# %% [markdown]
# # Exploring Spatial Grids
#
# Nelson Niu
# Nathaniel Osgood
# Priyaa Srinivasan
# Jacob Zelko
# Juxin Liu
# 2026-02-27
#
# ## Background
#
# ## Catlab Set-Up

# %%
import Catlab.CategoricalAlgebra:
  @acset,
  @acset_type,
  @acset_colim,
  @present,
  FreeSchema,
  elements,
  nparts,
  representable,
  set_subpart!,
  src,
  subobject_classifier,
  tgt,
  yoneda

# %% [markdown]
# We now examine a degenerate spatial grid, with one node in the middle

# %%
@present gridCenterCardinalDirections(FreeSchema) begin
  (N,S,E,W)::Ob  # top cell

  cell::Ob

  N2Cell::Hom(N,cell)
  S2Cell::Hom(S,cell)
  E2Cell::Hom(E,cell)
  W2Cell::Hom(W,cell)
end;

# %%
@acset_type gridCenterCardinalDirectionsInstance(gridCenterCardinalDirections)
# Out:
# gridCenterCardinalDirectionsInstance

# %%
ΩgridCenterGardinalDirections,dictΩZZ4TP  = subobject_classifier(gridCenterCardinalDirectionsInstance)
# Out:
# (gridCenterCardinalDirectionsInstance:
#   N = 1:3
#   S = 1:3
#   E = 1:3
#   W = 1:3
#   cell = 1:2
#   N2Cell : N → cell = [1, 1, 2]
#   S2Cell : S → cell = [1, 1, 2]
#   E2Cell : E → cell = [1, 1, 2]
#   W2Cell : W → cell = [1, 1, 2], Dict{Catlab.Theories.FreeSchema.Ob{:generator}, Vector{Catlab.CategoricalAlgebra.Cats.Subobjects.Subobject}}(N => [Catlab.CategoricalAlgebra.Cats.Subobjects.SubobjectHom{gridCenterCardinalDirectionsInstance, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:N, :S, :E, :W, :cell}, Tuple{(:N2Cell, :N, :cell), (:S2Cell, :S, :cell), (:E2Cell, :E, :cell), (:W2Cell, :W, :cell)}, Tuple{}, Tuple{}, Tuple{}}, @NamedTuple{N::Catlab.BasicSets.FinFunctions.FinFunction, W::Catlab.BasicSets.FinFunctions.FinFunction, cell::Catlab.BasicSets.FinFunctions.FinFunction, S::Catlab.BasicSets.FinFunctions.FinFunction, E::Catlab.BasicSets.FinFunctions.FinFunction}, gridCenterCardinalDirectionsInstance, gridCenterCardinalDirectionsInstance}}(ACSetTransformation((N = id(FinSet(1)), W = id(FinSet(0)), cell = id(FinSet(1)), S = id(FinSet(0)), E = id(FinSet(0))), )), Catlab.CategoricalAlgebra.Cats.Subobjects.SubobjectHom{gridCenterCardinalDirectionsInstance, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:N, :S, :E, :W, :cell}, Tuple{(:N2Cell, :N, :cell), (:S2Cell, :S, :cell), (:E2Cell, :E, :cell), (:W2Cell, :W, :cell)}, Tuple{}, Tuple{}, Tuple{}}, @NamedTuple{N::Catlab.BasicSets.FinFunctions.FinFunction, W::Catlab.BasicSets.FinFunctions.FinFunction, cell::Catlab.BasicSets.FinFunctions.FinFunction, S::Catlab.BasicSets.FinFunctions.FinFunction, E::Catlab.BasicSets.FinFunctions.FinFunction}, gridCenterCardinalDirectionsInstance, gridCenterCardinalDirectionsInstance}}(ACSetTransformation((N = FinFunction(Int64[], FinSet(1)), W = FinFunction(Int64[], FinSet(0)), cell = FinFunction([1], FinSet(1)), S = FinFunction(Int64[], FinSet(0)), E = FinFunction(Int64[], FinSet(0))), )), Catlab.CategoricalAlgebra.Cats.Subobjects.SubobjectHom{gridCenterCardinalDirectionsInstance, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:N, :S, :E, :W, :cell}, Tuple{(:N2Cell, :N, :cell), (:S2Cell, :S, :cell), (:E2Cell, :E, :cell), (:W2Cell, :W, :cell)}, Tuple{}, Tuple{}, Tuple{}}, @NamedTuple{N::Catlab.BasicSets.FinFunctions.FinFunction, W::Catlab.BasicSets.FinFunctions.FinFunction, cell::Catlab.BasicSets.FinFunctions.FinFunction, S::Catlab.BasicSets.FinFunctions.FinFunction, E::Catlab.BasicSets.FinFunctions.FinFunction}, gridCenterCardinalDirectionsInstance, gridCenterCardinalDirectionsInstance}}(ACSetTransformation((N = FinFunction(Int64[], FinSet(1)), W = FinFunction(Int64[], FinSet(0)), cell = FinFunction(Int64[], FinSet(1)), S = FinFunction(Int64[], FinSet(0)), E = FinFunction(Int64[], FinSet(0))), ))], S => [Catlab.CategoricalAlgebra.Cats.Subobjects.SubobjectHom{gridCenterCardinalDirectionsInstance, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:N, :S, :E, :W, :cell}, Tuple{(:N2Cell, :N, :cell), (:S2Cell, :S, :cell), (:E2Cell, :E, :cell), (:W2Cell, :W, :cell)}, Tuple{}, Tuple{}, Tuple{}}, @NamedTuple{N::Catlab.BasicSets.FinFunctions.FinFunction, W::Catlab.BasicSets.FinFunctions.FinFunction, cell::Catlab.BasicSets.FinFunctions.FinFunction, S::Catlab.BasicSets.FinFunctions.FinFunction, E::Catlab.BasicSets.FinFunctions.FinFunction}, gridCenterCardinalDirectionsInstance, gridCenterCardinalDirectionsInstance}}(ACSetTransformation((N = id(FinSet(0)), W = id(FinSet(0)), cell = id(FinSet(1)), S = id(FinSet(1)), E = id(FinSet(0))), )), Catlab.CategoricalAlgebra.Cats.Subobjects.SubobjectHom{gridCenterCardinalDirectionsInstance, Catlab.CategoricalAlgebra.Pointwise.ACSetTransformations.StructACSetTransformation{ACSets.Schemas.TypeLevelBasicSchema{Symbol, Tuple{:N, :S, :E, :W, :cell}, Tuple{(:N2Cell, :N, :cell), (:S2Cell, :S, :cell), (:E2Cell, :E, :cell), (:W2Cell, :W, :cell)}, Tuple{}, Tuple{}, Tuple{}}, @NamedTuple{N::C ...

# %%
@present grid3x3(FreeSchema) begin
  (c00,c01,c02)::Ob  # top row of cells
  (c10,c11,c12)::Ob  # left in middle row, middle cell, right cell in middle row
  (c20,c21,c22)::Ob  # bottom row of cells

  # wire up to central cell
  c01_to_c11::Hom(c01,c11)
  c10_to_c11::Hom(c10,c11)
  c12_to_c11::Hom(c12,c11)
  c21_to_c11::Hom(c21,c11)
end;
